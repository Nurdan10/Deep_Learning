# %% [markdown]
# ___
#
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid" alt="CLRSWY"></p>
#
# ___

# %% [markdown]
# <h1 style="text-align: center;">Deep Learning<br><br>Assignment-1 (ANN)<br><br>Churn Prediction for Bank Customer<br><h1>

# %% [markdown]
# # Dataset Info

# %% [markdown]
# We have a dataset in which there are details of a bank's customers and the target variable is a binary variable reflecting the fact whether the customer left the bank (closed his account) or he continues to be a customer.
#
# The features in the given dataset are:
# - **rownumber:** Row Numbers from 1 to 10000.
# - **customerid:** A unique ID that identifies each customer.
# - **surname:** The customer’s surname.
# - **creditscore:** A credit score is a number between 300–850 that depicts a consumer's creditworthiness.
# - **geography:** The country from which the customer belongs to.
# - **Gender:** The customer’s gender: Male, Female
# - **Age:** The customer’s current age, in years, at the time of being customer.
# - **tenure:** The number of years for which the customer has been with the bank.
# - **balance:** Bank balance of the customer.
# - **numofproducts:** the number of bank products the customer is utilising.
# - **hascrcard:** The number of credit cards given to the customer by the bank.
# - **isactivemember:** Binary Flag for indicating if the client is active or not with the bank before the moment where the client exits the company (recorded in the variable "exited")
# - **exited:** Binary flag 1 if the customer closed account with bank and 0 if the customer is retained.

# %% [markdown]
# # Improt Libraries & Data

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation

from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import RocCurveDisplay, roc_auc_score, PrecisionRecallDisplay
from sklearn.model_selection import cross_validate

# Uncomment the following lines if you want to suppress warnings:
# import warnings
# warnings.filterwarnings("ignore")
# warnings.warn("this will not show")

plt.rcParams["figure.figsize"] = (10, 6)

sns.set_style("whitegrid")
pd.set_option("display.float_format", lambda x: "%.3f" % x)

# Set it to None to display all rows in the dataframe:
# pd.set_option('display.max_rows', None)

# Set it to None to display all columns in the dataframe:
pd.set_option("display.max_columns", None)

# %%
# !pip install pandas

# %%
data = pd.read_csv("Churn_Modelling.csv")
df = data.copy()

# %% [markdown]
# # Exploratory Data Analysis and Visualization

# %% [markdown]
# 1. Implement basic steps to see how is your data looks like
# 2. Check for missing values
# 3. Drop the features that not suitable for modelling
# 4. Implement basic visualization steps such as histogram, countplot, heatmap
# 5. Convert categorical variables to dummy variables

# %%
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2      0.000              1          1               1
# 1       1  83807.860              1          0               1
# 2       8 159660.800              3          1               0
# 3       1      0.000              2          0               0
# 4       2 125510.820              1          1               1
#
#    EstimatedSalary  Exited
# 0       101348.880       1
# 1       112542.580       0
# 2       113931.570       1
# 3        93826.630       0
# ...

# %%
df.shape
# Out:
# (10000, 14)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           10000 non-null  object
#  6   Age              10000 non-null  int64
#  7   Tenure           10000 non-null  int64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(2), int64(9), object(3)
# memory usage: 1.1+ MB

# %%
df.describe().T
# Out:
#                     count         mean       std          min          25%  \
# RowNumber       10000.000     5000.500  2886.896        1.000     2500.750
# CustomerId      10000.000 15690940.569 71936.186 15565701.000 15628528.250
# CreditScore     10000.000      650.529    96.653      350.000      584.000
# Age             10000.000       38.922    10.488       18.000       32.000
# Tenure          10000.000        5.013     2.892        0.000        3.000
# Balance         10000.000    76485.889 62397.405        0.000        0.000
# NumOfProducts   10000.000        1.530     0.582        1.000        1.000
# HasCrCard       10000.000        0.706     0.456        0.000        0.000
# IsActiveMember  10000.000        0.515     0.500        0.000        0.000
# EstimatedSalary 10000.000   100090.240 57510.493       11.580    51002.110
# Exited          10000.000        0.204     0.403        0.000        0.000
#
#                          50%          75%          max
# ...

# %%
df.isnull().sum()
# Out:
# RowNumber          0
# CustomerId         0
# Surname            0
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.columns
# Out:
# Index(['RowNumber', 'CustomerId', 'Surname', 'CreditScore', 'Geography',
#        'Gender', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard',
#        'IsActiveMember', 'EstimatedSalary', 'Exited'],
#       dtype='object')

# %%
df = df.drop(columns=['RowNumber', 'CustomerId', 'Surname'])

# %%
numeric_features = ['CreditScore', 'Age', 'Tenure', 'EstimatedSalary']
for feature in numeric_features:
    plt.figure(figsize=(10, 6))
    sns.histplot(df[feature], bins=30, kde=True)
    plt.title(f'Histogram of {feature}')
    plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x='NumOfProducts', data=df)
plt.title('Bar Plot of NumOfProducts')
plt.xlabel('Number of Products')
plt.ylabel('Count')
plt.show()

# %%
categorical_features = ['Geography', 'Gender','HasCrCard', 'IsActiveMember', 'Exited']

for feature in categorical_features:
    plt.figure(figsize=(10, 6))
    sns.countplot(x=df[feature])
    plt.show()

# %%
df_numeric = df[['CreditScore', 'Age', 'Tenure', 'EstimatedSalary', 'Balance', 'NumOfProducts']]

plt.figure(figsize=(15, 10))

numeric_features = df_numeric.columns

for i, feature in enumerate(numeric_features):
    plt.subplot(2, 3, i + 1)  # 2x3'lük alt grafikler oluşturduk
    sns.boxplot(x=df_numeric[feature])
    plt.xlabel(feature)
    plt.ylabel('Value')

# %%
df[df['Age'] > 80][['Age']]
# Out:
#       Age
# 766    82
# 2458   88
# 3033   85
# 3387   84
# 3531   84
# 4931   81
# 6443   92
# 6759   92
# 7526   81
# 7956   81
# 9080   81
# 9309   83

# %%
df['NumOfProducts'].value_counts()
# Out:
# NumOfProducts
# 1    5084
# 2    4590
# 3     266
# 4      60
# Name: count, dtype: int64

# %%
df[df['CreditScore'] < 400]
# Out:
#       CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 7             376   Germany  Female   29       4 115046.740              4
# 942           376    France  Female   46       6      0.000              1
# 1193          363     Spain  Female   28       6 146098.430              3
# 1201          399   Germany    Male   46       2 127655.220              1
# 1405          359    France  Female   44       6 128747.690              1
# 1631          350     Spain    Male   54       1 152677.480              1
# 1838          350   Germany    Male   39       0 109733.200              2
# 1962          358     Spain  Female   52       8 143542.360              3
# 2473          351   Germany  Female   57       4 163146.460              1
# 2579          365   Germany    Male   30       0 127760.070              1
# 5285          386     Spain  Female   53       1 131955.070              1
# ...

# %%
df.groupby('EstimatedSalary')[['CreditScore']].mean()
# Out:
#                  CreditScore
# EstimatedSalary
# 11.580               709.000
# 90.070               625.000
# 91.750               645.000
# 96.270               710.000
# 106.670              629.000
# ...                      ...
# 199909.320           620.000
# 199929.170           569.000
# 199953.330           608.000
# 199970.740           639.000
# 199992.480           685.000
#
# [9999 rows x 1 columns]

# %%
df["Geography"].value_counts(normalize = True) * 100
# Out:
# Geography
# France    50.140
# Germany   25.090
# Spain     24.770
# Name: proportion, dtype: float64

# %%
df["Exited"].value_counts(normalize = True) * 100
# Out:
# Exited
# 0   79.630
# 1   20.370
# Name: proportion, dtype: float64

# %%
#sns.pairplot(df, hue = "Exited")

# %%
df_numeric = ['CreditScore', 'Age', 'Tenure', 'EstimatedSalary', 'Balance', 'NumOfProducts']
correlation_matrix = df[df_numeric].corr()

plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', center=0)
plt.title('Korelasyon Matrisi Isı Haritası')
plt.show()

# %%
plt.figure(figsize=(8, 10))
ax=df.corr(numeric_only = True)["Exited"].sort_values().drop("Exited").plot(kind="barh")
ax.bar_label(ax.containers[0], fmt="%.2f")
plt.show()

# %%
df = pd.get_dummies(df, columns=['Geography', 'Gender'], drop_first=True)

# %% [markdown]
# # Preprocessing of Data
# - Train | Test Split, Scalling

# %%
from sklearn.model_selection import train_test_split

# %%
X = df.drop('Exited', axis=1)
y = data['Exited']

# %%
import os

seed = 101
os.environ["TF_DETERMINISTIC_OPS"] = "1"

tf.keras.utils.set_random_seed(seed)

# %%
# Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(
    # Input data
    X, y,
    # Testing set size
    test_size=0.2,
    # Stratify the split based on the target variable
    stratify=y,
    # Seed for reproducibility
    random_state=seed
)

# Further split the training set into training and validation sets
X_train, X_val, y_train, y_val = train_test_split(
    # Training data
    X_train, y_train,
    # Validation set size
    test_size=0.1,
    # Stratify the split based on the target variable
    stratify=y_train,
    # Seed for reproducibility
    random_state=seed
)

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()

# %%
X_train = scaler.fit_transform(X_train)
X_val = scaler.transform(X_val)
X_test = scaler.transform(X_test)

# %% [markdown]
# # Modelling & Model Performance

# %%
print("Shape of train :", X_train.shape)
print("Shape of validation :", X_val.shape)
print("Shape of test :", X_test.shape)
# Out:
# Shape of train : (7200, 11)
# Shape of validation : (800, 11)
# Shape of test : (2000, 11)

# %% [markdown]
# ## without class_weigth

# %% [markdown]
# ### Create The Model

# %%
model = Sequential()

model.add(Dense(24, activation="relu", input_dim=X_train.shape[1]))
model.add(Dense(12, activation="relu"))
model.add(Dense(6, activation="relu"))
model.add(Dense(3, activation="relu"))
model.add(Dense(1, activation="sigmoid"))

model.compile(optimizer="adam", loss="binary_crossentropy", metrics=["Precision", "Recall"])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 24)                288
#
#  dense_1 (Dense)             (None, 12)                300
#
#  dense_2 (Dense)             (None, 6)                 78
#
#  dense_3 (Dense)             (None, 3)                 21
#
#  dense_4 (Dense)             (None, 1)                 4
#
# ...
# Total params: 691 (2.70 KB)
# Trainable params: 691 (2.70 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.fit(x=X_train,
          y=y_train,
          validation_data=(X_val, y_val),
          batch_size=36,
          epochs=1000)
# Out:
# Epoch 1/1000
# 200/200 [==============================] - 1s 2ms/step - loss: 0.5590 - precision: 0.2101 - recall: 0.0341 - val_loss: 0.4913 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 2/1000
# 200/200 [==============================] - 0s 1ms/step - loss: 0.4732 - precision: 0.6222 - recall: 0.0191 - val_loss: 0.4709 - val_precision: 1.0000 - val_recall: 0.0245
# Epoch 3/1000
# 200/200 [==============================] - 0s 1ms/step - loss: 0.4551 - precision: 0.5934 - recall: 0.1104 - val_loss: 0.4620 - val_precision: 0.4722 - val_recall: 0.2086
# Epoch 4/1000
# 200/200 [==============================] - 0s 1ms/step - loss: 0.4399 - precision: 0.6554 - recall: 0.1854 - val_loss: 0.4430 - val_precision: 0.5538 - val_recall: 0.2209
# Epoch 5/1000
# 200/200 [==============================] - 0s 1ms/step - loss: 0.4285 - precision: 0.6523 - recall: 0.2277 - val_loss: 0.4311 - val_precision: 0.5909 - val_recall: 0.2393
# Epoch 6/1000
# ...

# %%
loss_df = pd.DataFrame(model.history.history)
loss_df.head()
# Out:
#    loss  precision  recall  val_loss  val_precision  val_recall
# 0 0.559      0.210   0.034     0.491          0.000       0.000
# 1 0.473      0.622   0.019     0.471          1.000       0.025
# 2 0.455      0.593   0.110     0.462          0.472       0.209
# 3 0.440      0.655   0.185     0.443          0.554       0.221
# 4 0.428      0.652   0.228     0.431          0.591       0.239

# %%
# Create subplots
fig, axes = plt.subplots(2, 1, figsize=(8, 10))

# Plot loss
axes[0].plot(loss_df["loss"], label="Training Loss")
axes[0].plot(loss_df["val_loss"], label="Validation Loss")
axes[0].set_title("Model Loss")
axes[0].legend()

# Plot accuracy
axes[1].plot(loss_df["precision"], label="Training Precision")
axes[1].plot(loss_df["val_precision"], label="Validation Precision")
axes[1].set_title("Model Precision_Recall")
axes[1].legend()

axes[1].plot(loss_df["recall"], label="Training recall")
axes[1].plot(loss_df["val_recall"], label="Validation recall")
axes[1].legend()

# Show the plots
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Evaluate The Model
#
# - Plot the model history to observe the changing of metrics
# - Make prediction to see "confusion matrix" and "classification report"
# - Check ROC (Receiver Operating Curve) and AUC (Area Under Curve) for the model

# %%
loss_df.plot()
plt.show()

# %%
model.evaluate(X_test, y_test, verbose=0)
# Out:
# [0.4187825918197632, 0.6597222089767456, 0.46683046221733093]

# %%
loss, precision, recall = model.evaluate(X_test, y_test, verbose=0)
print("loss: ", loss)
print("precision: ", precision)
print("recall: ", recall)
# Out:
# loss:  0.4187825918197632
# precision:  0.6597222089767456
# recall:  0.46683046221733093

# %%
y_pred = model.predict(X_test) > 0.5
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# 63/63 [==============================] - 0s 745us/step
# [[1495   98]
#  [ 217  190]]
#               precision    recall  f1-score   support
#
#            0       0.87      0.94      0.90      1593
#            1       0.66      0.47      0.55       407
#
#     accuracy                           0.84      2000
#    macro avg       0.77      0.70      0.73      2000
# weighted avg       0.83      0.84      0.83      2000

# %%
y_pred_proba = model.predict(X_test)
RocCurveDisplay.from_predictions(y_test, y_pred_proba)
# Out:
# 63/63 [==============================] - 0s 824us/step

# %%
from sklearn.metrics import precision_recall_curve, average_precision_score, precision_score, recall_score
y_pred_proba = model.predict(X_test)

precision, recall, _ = precision_recall_curve(y_test, y_pred_proba)

average_precision = average_precision_score(y_test, y_pred_proba)

plt.plot(recall, precision, color='blue', lw=2, label=f'AP = {average_precision:.2f}')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve')
plt.legend(loc='best')
plt.show()
# Out:
# 63/63 [==============================] - 0s 987us/step

# %%
y_pred = model.predict(X_test) > 0.5
model_AP = average_precision_score(y_test, y_pred)
model_precision = precision_score(y_test, y_pred)
model_recall = recall_score(y_test, y_pred)
# Out:
# 63/63 [==============================] - 0s 773us/step

# %% [markdown]
# ## with class_weigth
#
# Investigate how the "class_weight" hyper-parameter is used in a Neural Network.

# %% [markdown]
# **The class_weight hyper-parameter is a useful tool in neural networks, particularly for handling imbalanced datasets. It allows you to assign different weights to different classes, giving the model an incentive to pay more attention to the less frequent classes. This can help improve the performance of the model on the minority class.**

# %%
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.utils.class_weight import compute_class_weight

def generate_binary_class_weights(y):
    """
    Generate class weights for binary classification based on the frequency of each class.

    Parameters:
    - y (array-like): Binary labels.

    Returns:
    dict: A dictionary with class labels as keys and their corresponding weights as values.
    """
    # Benzersiz sınıfları ve bu sınıfların sayısını bul
    unique_classes = np.unique(y)
    class_counts = [np.sum(y == cls) for cls in unique_classes]

    # Toplam örnek sayısını bul
    total_samples = len(y)

    # Sınıf ağırlıklarını hesapla
    class_weights = [total_samples / (len(unique_classes) * count) if count > 0 else 1 for count in class_counts]

    return dict(zip(unique_classes, class_weights))

# %%
print("Counts of classes \n", df.Exited.value_counts(), "\n\nProportions of classes: \n", df.Exited.value_counts(normalize = True))
print()
print("Weights of classes")
generate_binary_class_weights(y_train)
# Out:
# Counts of classes
#  Exited
# 0    7963
# 1    2037
# Name: count, dtype: int64
#
# Proportions of classes:
#  Exited
# 0   0.796
# 1   0.204
# Name: proportion, dtype: float64
#
# Weights of classes
# {0: 0.6279434850863422, 1: 2.4539877300613497}

# %% [markdown]
# ### Create The Model

# %%
model2 = Sequential()
model2.add(Dense(24, activation="relu", input_dim=X_train.shape[1]))
model2.add(Dense(12, activation="relu"))
model2.add(Dense(6, activation="relu"))
model2.add(Dense(1, activation="sigmoid"))

# Modeli derleme
model2.compile(optimizer="adam", loss="binary_crossentropy", metrics=[tf.keras.metrics.Precision(), tf.keras.metrics.Recall()])

# Sınıf ağırlıklarını hesaplama
class_weights = generate_binary_class_weights(y_train)

# Modeli eğitme
history = model2.fit(
    x=X_train,
    y=y_train,
    validation_data=(X_val, y_val),
    batch_size=36,
    epochs=1000,
    class_weight=class_weights
)
# Out:
# Epoch 1/1000
# 200/200 [==============================] - 1s 2ms/step - loss: 0.6830 - precision_1: 0.2223 - recall_1: 0.7751 - val_loss: 0.5681 - val_precision_1: 0.3422 - val_recall_1: 0.3926
# Epoch 2/1000
# 200/200 [==============================] - 0s 990us/step - loss: 0.6202 - precision_1: 0.3366 - recall_1: 0.6551 - val_loss: 0.5595 - val_precision_1: 0.3968 - val_recall_1: 0.6135
# Epoch 3/1000
# 200/200 [==============================] - 0s 1ms/step - loss: 0.5889 - precision_1: 0.3645 - recall_1: 0.6830 - val_loss: 0.6509 - val_precision_1: 0.3342 - val_recall_1: 0.7607
# Epoch 4/1000
# 200/200 [==============================] - 0s 995us/step - loss: 0.5704 - precision_1: 0.3865 - recall_1: 0.7205 - val_loss: 0.6301 - val_precision_1: 0.3499 - val_recall_1: 0.7791
# Epoch 5/1000
# 200/200 [==============================] - 0s 1ms/step - loss: 0.5569 - precision_1: 0.3949 - recall_1: 0.7287 - val_loss: 0.5766 - val_precision_1: 0.3873 - val_recall_1: 0.7485
# Epoch 6/1000
# ...

# %% [markdown]
# ### Evaluate The Model
#
# - Plot the model history to observe the changing of metrics
# - Make prediction to see "confusion matrix" and "classification report"
# - Check ROC (Receiver Operating Curve) and AUC (Area Under Curve) for the model

# %%
loss_df = pd.DataFrame(history.history)
loss_df.head()
# Out:
#    loss  precision_1  recall_1  val_loss  val_precision_1  val_recall_1
# 0 0.683        0.222     0.775     0.568            0.342         0.393
# 1 0.620        0.337     0.655     0.559            0.397         0.613
# 2 0.589        0.364     0.683     0.651            0.334         0.761
# 3 0.570        0.386     0.721     0.630            0.350         0.779
# 4 0.557        0.395     0.729     0.577            0.387         0.748

# %%
fig, axes = plt.subplots(2, 1, figsize=(8, 10))

# Kayıp grafiği
if 'loss' in loss_df.columns and 'val_loss' in loss_df.columns:
    axes[0].plot(loss_df["loss"], label="Training Loss")
    axes[0].plot(loss_df["val_loss"], label="Validation Loss")
    axes[0].set_title("Model Loss")
    axes[0].legend()

# Precision ve recall grafikleri
if 'precision_1' in loss_df.columns and 'val_precision_1' in loss_df.columns and 'recall_1' in loss_df.columns and 'val_recall_1' in loss_df.columns:
    axes[1].plot(loss_df["precision_1"], label="Training Precision")
    axes[1].plot(loss_df["val_precision_1"], label="Validation Precision")
    axes[1].plot(loss_df["recall_1"], label="Training Recall")
    axes[1].plot(loss_df["val_recall_1"], label="Validation Recall")
    axes[1].set_title("Model Precision and Recall")
    axes[1].legend()

# Grafiklerin gösterimi
plt.tight_layout()
plt.show()

# %%
loss, precision, recall = model2.evaluate(X_test, y_test, verbose=0)
print("loss: ", loss)
print("precision: ", precision)
print("recall: ", recall)
# Out:
# loss:  0.528227686882019
# precision:  0.46875
# recall:  0.6633906364440918

# %%
y_pred = model2.predict(X_test) > 0.5
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# 63/63 [==============================] - 0s 741us/step
# [[1287  306]
#  [ 137  270]]
#               precision    recall  f1-score   support
#
#            0       0.90      0.81      0.85      1593
#            1       0.47      0.66      0.55       407
#
#     accuracy                           0.78      2000
#    macro avg       0.69      0.74      0.70      2000
# weighted avg       0.82      0.78      0.79      2000

# %%
y_pred_proba = model2.predict(X_test)

precision, recall, _ = precision_recall_curve(y_test, y_pred_proba)

average_precision = average_precision_score(y_test, y_pred_proba)

plt.plot(recall, precision, color='blue', lw=2, label=f'AP = {average_precision:.2f}')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve')
plt.legend(loc='best')
plt.show()
# Out:
# 63/63 [==============================] - 0s 707us/step

# %%
y_pred = model2.predict(X_test) > 0.5
model2_AP = average_precision_score(y_test, y_pred)
model2_precision = precision_score(y_test, y_pred)
model2_recall = recall_score(y_test, y_pred)
# Out:
# 63/63 [==============================] - 0s 613us/step

# %% [markdown]
# ## Implementation Different Methods to Develop The Model
#
# - Implement the following methods on model creating with "class_weight" parameter
# - Create and evaluate model for each method

# %% [markdown]
# ### Increase The Learning Rate and Observe The Results

# %%
from tensorflow.keras.optimizers import Adam
learning_rate = 0.003

# %%
model3 = Sequential()

model3.add(Dense(24, activation="relu", input_dim=X_train.shape[1]))
model3.add(Dense(12, activation="relu"))
model3.add(Dense(6, activation="relu"))
model3.add(Dense(3, activation="relu"))
model3.add(Dense(1, activation="sigmoid"))

opt=Adam(learning_rate = learning_rate)
model3.compile(optimizer=opt, loss="binary_crossentropy", metrics=["Precision", "Recall"])

# %%
model3.fit(
    x=X_train,
    y=y_train,
    validation_data=(X_val, y_val),
    batch_size=36,
    epochs=1000,
    class_weight=generate_binary_class_weights(y_train)
)
# Out:
# Epoch 1/1000
# 200/200 [==============================] - 1s 3ms/step - loss: 0.6627 - precision: 0.2670 - recall: 0.7580 - val_loss: 0.6799 - val_precision: 0.3584 - val_recall: 0.6135
# Epoch 2/1000
# 200/200 [==============================] - 0s 994us/step - loss: 0.6159 - precision: 0.3639 - recall: 0.6646 - val_loss: 0.6065 - val_precision: 0.4133 - val_recall: 0.5706
# Epoch 3/1000
# 200/200 [==============================] - 0s 989us/step - loss: 0.5852 - precision: 0.3881 - recall: 0.7069 - val_loss: 0.6866 - val_precision: 0.3350 - val_recall: 0.8282
# Epoch 4/1000
# 200/200 [==============================] - 0s 973us/step - loss: 0.5562 - precision: 0.4092 - recall: 0.7355 - val_loss: 0.5900 - val_precision: 0.4088 - val_recall: 0.7975
# Epoch 5/1000
# 200/200 [==============================] - 0s 987us/step - loss: 0.5218 - precision: 0.4389 - recall: 0.7321 - val_loss: 0.5675 - val_precision: 0.4272 - val_recall: 0.7914
# Epoch 6/1000
# ...

# %%
loss_df = pd.DataFrame(model3.history.history)
loss_df.head()
# Out:
#    loss  precision  recall  val_loss  val_precision  val_recall
# 0 0.663      0.267   0.758     0.680          0.358       0.613
# 1 0.616      0.364   0.665     0.607          0.413       0.571
# 2 0.585      0.388   0.707     0.687          0.335       0.828
# 3 0.556      0.409   0.736     0.590          0.409       0.798
# 4 0.522      0.439   0.732     0.567          0.427       0.791

# %%
fig, axes = plt.subplots(2, 1, figsize=(8, 10))

# Kayıp grafiği
if 'loss' in loss_df.columns and 'val_loss' in loss_df.columns:
    axes[0].plot(loss_df["loss"], label="Training Loss")
    axes[0].plot(loss_df["val_loss"], label="Validation Loss")
    axes[0].set_title("Model Loss")
    axes[0].legend()

# Precision ve recall grafikleri
if 'precision' in loss_df.columns and 'val_precision' in loss_df.columns and 'recall' in loss_df.columns and 'val_recall' in loss_df.columns:
    axes[1].plot(loss_df["precision"], label="Training Precision")
    axes[1].plot(loss_df["val_precision"], label="Validation Precision")
    axes[1].plot(loss_df["recall"], label="Training Recall")
    axes[1].plot(loss_df["val_recall"], label="Validation Recall")
    axes[1].set_title("Model Precision and Recall")
    axes[1].legend()

# Grafiklerin gösterimi
plt.tight_layout()
plt.show()

# %%
loss, precision, recall = model3.evaluate(X_test, y_test, verbose=0)
print("loss: ", loss)
print("precision: ", precision)
print("recall: ", recall)
# Out:
# loss:  0.5875060558319092
# precision:  0.4364820718765259
# recall:  0.6584766507148743

# %%
y_pred = model3.predict(X_test) > 0.5
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# 63/63 [==============================] - 0s 760us/step
# [[1247  346]
#  [ 139  268]]
#               precision    recall  f1-score   support
#
#            0       0.90      0.78      0.84      1593
#            1       0.44      0.66      0.52       407
#
#     accuracy                           0.76      2000
#    macro avg       0.67      0.72      0.68      2000
# weighted avg       0.81      0.76      0.77      2000

# %%
y_pred_proba = model3.predict(X_test)

precision, recall, _ = precision_recall_curve(y_test, y_pred_proba)

average_precision = average_precision_score(y_test, y_pred_proba)

plt.plot(recall, precision, color='blue', lw=2, label=f'AP = {average_precision:.2f}')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve')
plt.legend(loc='best')
plt.show()
# Out:
# 63/63 [==============================] - 0s 673us/step

# %%
y_pred = model3.predict(X_test) > 0.5
model3_AP = average_precision_score(y_test, y_pred)
model3_precision = precision_score(y_test, y_pred)
model3_recall = recall_score(y_test, y_pred)
# Out:
# 63/63 [==============================] - 0s 802us/step

# %% [markdown]
# ### Add Dropout Layer

# %%
from tensorflow.keras.layers import Dropout

# %%
model4 = Sequential()

model4.add(Dense(24, activation="relu", input_dim=X_train.shape[1]))
model4.add(Dropout(0.5))

model4.add(Dense(12, activation="relu"))
model4.add(Dropout(0.5))

model4.add(Dense(6, activation="relu"))
model4.add(Dropout(0.5))

model4.add(Dense(3, activation="relu"))
model4.add(Dropout(0.5))

model4.add(Dense(1, activation="sigmoid"))

opt=Adam(learning_rate = learning_rate)
model4.compile(optimizer=opt, loss="binary_crossentropy", metrics=["Precision", "Recall"])

# %%
model4.fit(
    x=X_train,
    y=y_train,
    validation_data=(X_val, y_val),
    batch_size=36,
    epochs=1000,
    class_weight=generate_binary_class_weights(y_train)
)
# Out:
# Epoch 1/1000
# 200/200 [==============================] - 1s 3ms/step - loss: 0.6970 - precision: 0.2023 - recall: 0.8241 - val_loss: 0.6886 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 2/1000
# 200/200 [==============================] - 0s 1ms/step - loss: 0.6935 - precision: 0.1953 - recall: 0.5358 - val_loss: 0.6937 - val_precision: 0.2037 - val_recall: 1.0000
# Epoch 3/1000
# 200/200 [==============================] - 0s 1ms/step - loss: 0.6936 - precision: 0.1971 - recall: 0.2808 - val_loss: 0.6905 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 4/1000
# 200/200 [==============================] - 0s 1ms/step - loss: 0.6933 - precision: 0.1956 - recall: 0.5324 - val_loss: 0.6883 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 5/1000
# 200/200 [==============================] - 0s 1ms/step - loss: 0.6933 - precision: 0.2096 - recall: 0.1513 - val_loss: 0.6983 - val_precision: 0.2037 - val_recall: 1.0000
# Epoch 6/1000
# ...

# %%
loss_df = pd.DataFrame(model4.history.history)
loss_df.head()
# Out:
#    loss  precision  recall  val_loss  val_precision  val_recall
# 0 0.697      0.202   0.824     0.689          0.000       0.000
# 1 0.694      0.195   0.536     0.694          0.204       1.000
# 2 0.694      0.197   0.281     0.690          0.000       0.000
# 3 0.693      0.196   0.532     0.688          0.000       0.000
# 4 0.693      0.210   0.151     0.698          0.204       1.000

# %%
fig, axes = plt.subplots(2, 1, figsize=(8, 10))

# Kayıp grafiği
if 'loss' in loss_df.columns and 'val_loss' in loss_df.columns:
    axes[0].plot(loss_df["loss"], label="Training Loss")
    axes[0].plot(loss_df["val_loss"], label="Validation Loss")
    axes[0].set_title("Model Loss")
    axes[0].legend()

# Precision ve recall grafikleri
if 'precision' in loss_df.columns and 'val_precision' in loss_df.columns and 'recall' in loss_df.columns and 'val_recall' in loss_df.columns:
    axes[1].plot(loss_df["precision"], label="Training Precision")
    axes[1].plot(loss_df["val_precision"], label="Validation Precision")
    axes[1].plot(loss_df["recall"], label="Training Recall")
    axes[1].plot(loss_df["val_recall"], label="Validation Recall")
    axes[1].set_title("Model Precision and Recall")
    axes[1].legend()

# Grafiklerin gösterimi
plt.tight_layout()
plt.show()

# %%
loss, precision, recall = model4.evaluate(X_test, y_test, verbose=0)
print("loss: ", loss)
print("precision: ", precision)
print("recall: ", recall)
# Out:
# loss:  0.5436254739761353
# precision:  0.4171122908592224
# recall:  0.7665847539901733

# %%
y_pred = model4.predict(X_test) > 0.5
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# 63/63 [==============================] - 0s 707us/step
# [[1157  436]
#  [  95  312]]
#               precision    recall  f1-score   support
#
#            0       0.92      0.73      0.81      1593
#            1       0.42      0.77      0.54       407
#
#     accuracy                           0.73      2000
#    macro avg       0.67      0.75      0.68      2000
# weighted avg       0.82      0.73      0.76      2000

# %%
y_pred_proba = model4.predict(X_test)

precision, recall, _ = precision_recall_curve(y_test, y_pred_proba)

model4_average_precision = average_precision_score(y_test, y_pred_proba)

plt.plot(recall, precision, color='blue', lw=2, label=f'AP = {model4_average_precision:.2f}')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve')
plt.legend(loc='best')
plt.show()
# Out:
# 63/63 [==============================] - 0s 937us/step

# %%
y_pred = model4.predict(X_test) > 0.5
model4_AP = average_precision_score(y_test, y_pred)
model4_precision = precision_score(y_test, y_pred)
model4_recall = recall_score(y_test, y_pred)
# Out:
# 63/63 [==============================] - 0s 778us/step

# %% [markdown]
# ### Add Early Stop

# %%
from tensorflow.keras.callbacks import EarlyStopping

# %%
from tensorflow.keras.optimizers import Adam
model5 = Sequential()

model5.add(Dense(24, activation="relu", input_dim=X_train.shape[1]))
model5.add(Dense(12, activation="relu"))
model5.add(Dense(6, activation="relu"))
model5.add(Dense(3, activation="relu"))
model5.add(Dense(1, activation="sigmoid"))


opt=Adam(learning_rate = learning_rate)
model5.compile(optimizer=opt, loss="binary_crossentropy", metrics=["Precision", "Recall"])

# %% [markdown]
# #### Monitor the "val_loss" as metric

# %%
early_stop = EarlyStopping(
    monitor="val_loss", mode="min", verbose=1, patience=15, restore_best_weights=True
)

# %%
model5.fit(
    x=X_train,
    y=y_train,
    validation_data=(X_val, y_val),
    batch_size=36,
    epochs=1000,
    class_weight=generate_binary_class_weights(y_train),
    callbacks=[early_stop]
)
# Out:
# Epoch 1/1000
# 200/200 [==============================] - 1s 2ms/step - loss: 0.6642 - precision: 0.3399 - recall: 0.5201 - val_loss: 0.5827 - val_precision: 0.3520 - val_recall: 0.6564
# Epoch 2/1000
# 200/200 [==============================] - 0s 1ms/step - loss: 0.6197 - precision: 0.3526 - recall: 0.7035 - val_loss: 0.5480 - val_precision: 0.4036 - val_recall: 0.6933
# Epoch 3/1000
# 200/200 [==============================] - 0s 1ms/step - loss: 0.5896 - precision: 0.3774 - recall: 0.7144 - val_loss: 0.6222 - val_precision: 0.3357 - val_recall: 0.8650
# Epoch 4/1000
# 200/200 [==============================] - 0s 1ms/step - loss: 0.5620 - precision: 0.3891 - recall: 0.7566 - val_loss: 0.5557 - val_precision: 0.4053 - val_recall: 0.8405
# Epoch 5/1000
# 200/200 [==============================] - 0s 1ms/step - loss: 0.5305 - precision: 0.4296 - recall: 0.7614 - val_loss: 0.5314 - val_precision: 0.4132 - val_recall: 0.8466
# Epoch 6/1000
# ...

# %%
loss_df = pd.DataFrame(model5.history.history)
loss_df.head()
# Out:
#    loss  precision  recall  val_loss  val_precision  val_recall
# 0 0.664      0.340   0.520     0.583          0.352       0.656
# 1 0.620      0.353   0.703     0.548          0.404       0.693
# 2 0.590      0.377   0.714     0.622          0.336       0.865
# 3 0.562      0.389   0.757     0.556          0.405       0.840
# 4 0.530      0.430   0.761     0.531          0.413       0.847

# %%
fig, axes = plt.subplots(2, 1, figsize=(8, 10))

# Kayıp grafiği
if 'loss' in loss_df.columns and 'val_loss' in loss_df.columns:
    axes[0].plot(loss_df["loss"], label="Training Loss")
    axes[0].plot(loss_df["val_loss"], label="Validation Loss")
    axes[0].set_title("Model Loss")
    axes[0].legend()

# Precision ve recall grafikleri
if 'precision' in loss_df.columns and 'val_precision' in loss_df.columns and 'recall' in loss_df.columns and 'val_recall' in loss_df.columns:
    axes[1].plot(loss_df["precision"], label="Training Precision")
    axes[1].plot(loss_df["val_precision"], label="Validation Precision")
    axes[1].plot(loss_df["recall"], label="Training Recall")
    axes[1].plot(loss_df["val_recall"], label="Validation Recall")
    axes[1].set_title("Model Precision and Recall")
    axes[1].legend()

# Grafiklerin gösterimi
plt.tight_layout()
plt.show()

# %%
loss, precision, recall = model5.evaluate(X_test, y_test, verbose=0)
print("loss: ", loss)
print("precision: ", precision)
print("recall: ", recall)
# Out:
# loss:  0.4263806641101837
# precision:  0.5214446783065796
# recall:  0.5675675868988037

# %%
y_pred = model5.predict(X_test) > 0.5
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# 63/63 [==============================] - 0s 739us/step
# [[1381  212]
#  [ 176  231]]
#               precision    recall  f1-score   support
#
#            0       0.89      0.87      0.88      1593
#            1       0.52      0.57      0.54       407
#
#     accuracy                           0.81      2000
#    macro avg       0.70      0.72      0.71      2000
# weighted avg       0.81      0.81      0.81      2000

# %%
y_pred_proba = model5.predict(X_test)

precision, recall, _ = precision_recall_curve(y_test, y_pred_proba)

average_precision = average_precision_score(y_test, y_pred_proba)

plt.plot(recall, precision, color='blue', lw=2, label=f'AP = {average_precision:.2f}')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve')
plt.legend(loc='best')
plt.show()
# Out:
# 63/63 [==============================] - 0s 647us/step

# %%
y_pred = model5.predict(X_test) > 0.5
model5_AP = average_precision_score(y_test, y_pred)
model5_precision = precision_score(y_test, y_pred)
model5_recall = recall_score(y_test, y_pred)
# Out:
# 63/63 [==============================] - 0s 726us/step

# %% [markdown]
# #### Monitor the "val_precision" as metric

# %%
early_stop_precision = EarlyStopping(
    monitor="val_precision_1",  # Burada val_precision_1 yerine val_precision yazabilirsiniz.
    mode="max",
    verbose=1,
    patience=15,
    restore_best_weights=True
)

# %%
from tensorflow.keras.optimizers import Adam
model6 = Sequential()

model6.add(Dense(24, activation="relu", input_dim=X_train.shape[1]))
model6.add(Dense(12, activation="relu"))
model6.add(Dense(6, activation="relu"))
model6.add(Dense(3, activation="relu"))
model6.add(Dense(1, activation="sigmoid"))


opt=Adam(learning_rate = learning_rate)
model6.compile(optimizer=opt, loss="binary_crossentropy", metrics=["Precision", "Recall"])

# %%
model6.fit(
    x=X_train,
    y=y_train,
    validation_data=(X_val, y_val),
    batch_size=36,
    epochs=1000,
    class_weight=generate_binary_class_weights(y_train),
    callbacks=[early_stop]
)
# Out:
# Epoch 1/1000
# 200/200 [==============================] - 1s 2ms/step - loss: 0.6551 - precision: 0.2781 - recall: 0.7498 - val_loss: 0.6659 - val_precision: 0.3904 - val_recall: 0.6012
# Epoch 2/1000
# 200/200 [==============================] - 0s 1ms/step - loss: 0.6014 - precision: 0.3940 - recall: 0.6449 - val_loss: 0.5906 - val_precision: 0.4526 - val_recall: 0.5276
# Epoch 3/1000
# 200/200 [==============================] - 0s 1ms/step - loss: 0.5662 - precision: 0.4478 - recall: 0.6435 - val_loss: 0.6677 - val_precision: 0.3934 - val_recall: 0.8037
# Epoch 4/1000
# 200/200 [==============================] - 0s 1ms/step - loss: 0.5297 - precision: 0.4780 - recall: 0.6967 - val_loss: 0.5511 - val_precision: 0.4837 - val_recall: 0.7301
# Epoch 5/1000
# 200/200 [==============================] - 0s 1ms/step - loss: 0.5077 - precision: 0.4793 - recall: 0.7021 - val_loss: 0.5553 - val_precision: 0.4686 - val_recall: 0.7791
# Epoch 6/1000
# ...

# %%
loss_df = pd.DataFrame(model6.history.history)
loss_df.head()
# Out:
#    loss  precision  recall  val_loss  val_precision  val_recall
# 0 0.655      0.278   0.750     0.666          0.390       0.601
# 1 0.601      0.394   0.645     0.591          0.453       0.528
# 2 0.566      0.448   0.643     0.668          0.393       0.804
# 3 0.530      0.478   0.697     0.551          0.484       0.730
# 4 0.508      0.479   0.702     0.555          0.469       0.779

# %%
fig, axes = plt.subplots(2, 1, figsize=(8, 10))

# Kayıp grafiği
if 'loss' in loss_df.columns and 'val_loss' in loss_df.columns:
    axes[0].plot(loss_df["loss"], label="Training Loss")
    axes[0].plot(loss_df["val_loss"], label="Validation Loss")
    axes[0].set_title("Model Loss")
    axes[0].legend()

# Precision ve recall grafikleri
if 'precision' in loss_df.columns and 'val_precision' in loss_df.columns and 'recall' in loss_df.columns and 'val_recall' in loss_df.columns:
    axes[1].plot(loss_df["precision"], label="Training Precision")
    axes[1].plot(loss_df["val_precision"], label="Validation Precision")
    axes[1].plot(loss_df["recall"], label="Training Recall")
    axes[1].plot(loss_df["val_recall"], label="Validation Recall")
    axes[1].set_title("Model Precision and Recall")
    axes[1].legend()

# Grafiklerin gösterimi
plt.tight_layout()
plt.show()

# %%
loss, precision, recall = model6.evaluate(X_test, y_test, verbose=0)
print("loss: ", loss)
print("precision: ", precision)
print("recall: ", recall)
# Out:
# loss:  0.4361567497253418
# precision:  0.5299145579338074
# recall:  0.6093366146087646

# %%
y_pred = model6.predict(X_test) > 0.5
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# 63/63 [==============================] - 0s 769us/step
# [[1373  220]
#  [ 159  248]]
#               precision    recall  f1-score   support
#
#            0       0.90      0.86      0.88      1593
#            1       0.53      0.61      0.57       407
#
#     accuracy                           0.81      2000
#    macro avg       0.71      0.74      0.72      2000
# weighted avg       0.82      0.81      0.82      2000

# %%
y_pred_proba = model6.predict(X_test)

precision, recall, _ = precision_recall_curve(y_test, y_pred_proba)

average_precision = average_precision_score(y_test, y_pred_proba)

plt.plot(recall, precision, color='blue', lw=2, label=f'AP = {average_precision:.2f}')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve')
plt.legend(loc='best')
plt.show()
# Out:
# 63/63 [==============================] - 0s 785us/step

# %%
y_pred = model6.predict(X_test) > 0.5
model6_AP = average_precision_score(y_test, y_pred)
model6_precision = precision_score(y_test, y_pred)
model6_recall = recall_score(y_test, y_pred)
# Out:
# 63/63 [==============================] - 0s 743us/step

# %% [markdown]
# #### Monitor the "val_recall" as metric

# %%
early_stop = EarlyStopping(
    monitor="val_recall", mode="max", verbose=1, patience=15, restore_best_weights=True
)

# %%
from tensorflow.keras.optimizers import Adam
model7 = Sequential()

model7.add(Dense(24, activation="relu", input_dim=X_train.shape[1]))
model7.add(Dense(12, activation="relu"))
model7.add(Dense(6, activation="relu"))
model7.add(Dense(3, activation="relu"))
model7.add(Dense(1, activation="sigmoid"))

opt=Adam(learning_rate = learning_rate)
model7.compile(optimizer=opt, loss="binary_crossentropy", metrics=["Precision", "Recall"])

# %%
model7.fit(
    x=X_train,
    y=y_train,
    validation_data=(X_val, y_val),
    batch_size=36,
    epochs=1000,
    class_weight=generate_binary_class_weights(y_train),
    callbacks=[early_stop]
)
# Out:
# Epoch 1/1000
# 200/200 [==============================] - 1s 3ms/step - loss: 0.6424 - precision: 0.3804 - recall: 0.4942 - val_loss: 0.6246 - val_precision: 0.3645 - val_recall: 0.7178
# Epoch 2/1000
# 200/200 [==============================] - 0s 1ms/step - loss: 0.5730 - precision: 0.3884 - recall: 0.6967 - val_loss: 0.5532 - val_precision: 0.4307 - val_recall: 0.7055
# Epoch 3/1000
# 200/200 [==============================] - 0s 1ms/step - loss: 0.5347 - precision: 0.4167 - recall: 0.7226 - val_loss: 0.6084 - val_precision: 0.3850 - val_recall: 0.8528
# Epoch 4/1000
# 200/200 [==============================] - 0s 1ms/step - loss: 0.4988 - precision: 0.4374 - recall: 0.7546 - val_loss: 0.5072 - val_precision: 0.4573 - val_recall: 0.8221
# Epoch 5/1000
# 200/200 [==============================] - 0s 1ms/step - loss: 0.4828 - precision: 0.4656 - recall: 0.7478 - val_loss: 0.5415 - val_precision: 0.4375 - val_recall: 0.8589
# Epoch 6/1000
# ...

# %%
loss_df = pd.DataFrame(model7.history.history)
loss_df.head()
# Out:
#    loss  precision  recall  val_loss  val_precision  val_recall
# 0 0.642      0.380   0.494     0.625          0.364       0.718
# 1 0.573      0.388   0.697     0.553          0.431       0.706
# 2 0.535      0.417   0.723     0.608          0.385       0.853
# 3 0.499      0.437   0.755     0.507          0.457       0.822
# 4 0.483      0.466   0.748     0.541          0.438       0.859

# %%
fig, axes = plt.subplots(2, 1, figsize=(8, 10))

# Kayıp grafiği
if 'loss' in loss_df.columns and 'val_loss' in loss_df.columns:
    axes[0].plot(loss_df["loss"], label="Training Loss")
    axes[0].plot(loss_df["val_loss"], label="Validation Loss")
    axes[0].set_title("Model Loss")
    axes[0].legend()

# Precision ve recall grafikleri
if 'precision' in loss_df.columns and 'val_precision' in loss_df.columns and 'recall' in loss_df.columns and 'val_recall' in loss_df.columns:
    axes[1].plot(loss_df["precision"], label="Training Precision")
    axes[1].plot(loss_df["val_precision"], label="Validation Precision")
    axes[1].plot(loss_df["recall"], label="Training Recall")
    axes[1].plot(loss_df["val_recall"], label="Validation Recall")
    axes[1].set_title("Model Precision and Recall")
    axes[1].legend()

# Grafiklerin gösterimi
plt.tight_layout()
plt.show()

# %%
loss, precision, recall = model7.evaluate(X_test, y_test, verbose=0)
print("loss: ", loss)
print("precision: ", precision)
print("recall: ", recall)
# Out:
# loss:  0.5963647961616516
# precision:  0.3705815374851227
# recall:  0.7985258102416992

# %%
y_pred = model7.predict(X_test) > 0.5 # model.predict gives us probability.
                                      # The assignment is established by setting it to 0.5; it cannot be used on its own
print(classification_report(y_test, y_pred))
# Out:
# 63/63 [==============================] - 0s 694us/step
#               precision    recall  f1-score   support
#
#            0       0.93      0.65      0.77      1593
#            1       0.37      0.80      0.51       407
#
#     accuracy                           0.68      2000
#    macro avg       0.65      0.73      0.64      2000
# weighted avg       0.81      0.68      0.71      2000

# %%
y_pred_proba = model7.predict(X_test)

precision, recall, _ = precision_recall_curve(y_test, y_pred_proba)

average_precision = average_precision_score(y_test, y_pred_proba)

plt.plot(recall, precision, color='blue', lw=2, label=f'AP = {average_precision:.2f}')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve')
plt.legend(loc='best')
plt.show()
# Out:
# 63/63 [==============================] - 0s 2ms/step

# %%
y_pred = model7.predict(X_test) > 0.5
model7_AP = average_precision_score(y_test, y_pred)
model7_precision = precision_score(y_test, y_pred)
model7_recall = recall_score(y_test, y_pred)
# Out:
# 63/63 [==============================] - 0s 795us/step

# %% [markdown]
# ## Optuna

# %%
#!pip install optuna
# Out:
# ...
#   Using cached tqdm-4.66.4-py3-none-any.whl.metadata (57 kB)
# ...
#    ---------------------------------------- 0.0/380.1 kB ? eta -:--:--
#    ---- ---------------------------------- 41.0/380.1 kB 991.0 kB/s eta 0:00:01
#    ------------------ --------------------- 174.1/380.1 kB 2.1 MB/s eta 0:00:01
#    -------------------------------------- - 368.6/380.1 kB 2.9 MB/s eta 0:00:01
#    ---------------------------------------- 380.1/380.1 kB 3.0 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/233.0 kB ? eta -:--:--
#    ---------------------------------------- 233.0/233.0 kB 7.2 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ------ --------------------------------- 0.3/2.1 MB 7.2 MB/s eta 0:00:01
#    ------------- -------------------------- 0.7/2.1 MB 7.3 MB/s eta 0:00:01
#    --------------------- ------------------ 1.1/2.1 MB 7.8 MB/s eta 0:00:01
# ...

# %%
from tensorflow.keras.optimizers import Adam, Adadelta, RMSprop, Nadam
import optuna
from optuna.trial import Trial

# %%
early_stop = EarlyStopping(
    monitor="val_loss", mode="min", verbose=1, patience=15, restore_best_weights=True
)

# %%
def create_model(trial):
    n_units1 = trial.suggest_int("n_units1", 8, 128)
    n_units2 = trial.suggest_int("n_units2", 8, 128)
    optimizer = trial.suggest_categorical("optimizer", [Adam, Adadelta, RMSprop, Nadam])
    learning_rate = trial.suggest_loguniform("learning_rate", 1e-5, 1.3e-1)

    model = Sequential()
    model.add(Dense(n_units1, input_dim=X_train.shape[1], activation="relu"))
    model.add(Dense(n_units2, activation="relu"))
    model.add(Dense(1, activation="sigmoid"))
    model.compile(
        loss="binary_crossentropy",
        optimizer=optimizer(learning_rate=learning_rate),
        metrics=[Recall()],
    )
    return model

def objective(trial):
    model = create_model(trial)
    w0 = trial.suggest_loguniform("w0", 0.01, 5)
    w1 = trial.suggest_loguniform("w1", 0.01, 5)
    history = model.fit(
        X_train,
        y_train,
        validation_data=(X_test, y_test),
        batch_size=batch_size,
        epochs=100,
        callbacks=[early_stop],
        class_weight={0: w0, 1: w1},
        verbose=0,
    )
    recall = history.history['val_recall'][-1]
    return recall

# Create and run the study
study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=50)

# Print the best hyperparameters and score
print("Best hyperparameters: ", study.best_params)
print("Best recall score: ", study.best_value)

# Train and evaluate the final model with best hyperparameters
best_params = study.best_params
final_model = create_model(optuna.trial.FixedTrial(best_params))
final_model.fit(
    X_train,
    y_train,
    validation_data=(X_test, y_test),
    batch_size=batch_size,
    epochs=100,
    callbacks=[early_stop],
    class_weight={0: best_params['w0'], 1: best_params['w1']},
    verbose=1,
)
final_score = final_model.evaluate(X_test, y_test, verbose=0)
print("Final model recall on test set: ", final_score[1])
# Out:
# [I 2024-07-21 22:46:37,056] A new study created in memory with name: no-name-e9128f62-4e3f-4c4d-b988-e93f3e2a97f2
# C:\Users\nurda\AppData\Local\Temp\ipykernel_15636\1491145154.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 1e-5, 1.3e-1)
# [W 2024-07-21 22:46:37,084] Trial 0 failed with parameters: {'n_units1': 72, 'n_units2': 74, 'optimizer': <class 'keras.src.optimizers.rmsprop.RMSprop'>, 'learning_rate': 0.0006024045240595677} because of the following error: NameError("name 'Recall' is not defined").
# Traceback (most recent call last):
#   File "C:\Users\nurda\anaconda3\envs\kerasenv\lib\site-packages\optuna\study\_optimize.py", line 196, in _run_trial
#     value_or_values = func(trial)
# ...

# %%
study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=50) 
print("Best hyperparameters: ", study.best_params)
print("Best recall score: ", study.best_value)
# Out:
# [I 2024-07-21 22:45:00,042] A new study created in memory with name: no-name-36de72b9-2f72-4345-8734-3ceec5018403
# C:\Users\nurda\AppData\Local\Temp\ipykernel_15636\2278733354.py:9: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 1e-5, 1.3e-1)
# [W 2024-07-21 22:45:00,069] Trial 0 failed with parameters: {'n_units1': 51, 'n_units2': 48, 'optimizer': <class 'keras.src.optimizers.nadam.Nadam'>, 'learning_rate': 0.00022857111246393384} because of the following error: TypeError("'numpy.ndarray' object is not callable").
# Traceback (most recent call last):
#   File "C:\Users\nurda\anaconda3\envs\kerasenv\lib\site-packages\optuna\study\_optimize.py", line 196, in _run_trial
#     value_or_values = func(trial)
# ...

# %%
# Retrieve the best hyperparameters
best_params = study.best_params

# Create and train the final model
final_model = create_model(optuna.trial.FixedTrial(best_params))
final_model.fit(
    X_train,
    y_train,
    validation_data=(X_test, y_test),
    batch_size=batch_size,
    epochs=100,
    callbacks=[early_stop],
    class_weight={0: best_params['w0'], 1: best_params['w1']},
    verbose=1,
)

# Evaluate the final model
final_score = final_model.evaluate(X_test, y_test, verbose=0)
print("Final model recall on test set: ", final_score[1])

# %%
unit1, unit2, unit3,unit4, optimizer, lr, w0, w1 = (
    study.best_params["n_units1"],
    study.best_params["n_units2"],
    study.best_params["n_units3"],
    study.best_params["n_units4"],
    study.best_params["optimizer"],
    study.best_params["learning_rate"],
    study.best_params["w0"],
    study.best_params["w1"],
)

model7 = Sequential()

model7.add(Dense(unit1, activation="relu", input_dim=X_train.shape[1])) 
model7.add(Dense(unit2, activation="relu"))
model7.add(Dense(unit3, activation="relu"))
model7.add(Dense(unit4, activation="relu"))
model7.add(Dense(1, activation="sigmoid"))

opt = optimizer(learning_rate=lr)
model7.compile(optimizer=opt, loss="binary_crossentropy", metrics=["Recall"])

model7.fit(
    X_train,
    y_train,
    validation_data=(X_val, y_val),
    batch_size=64,
    epochs=500,
    callbacks=[early_stop],
    class_weight={0: w0, 1: w1},
    verbose=1,
)
# Out:
# Epoch 1/500
# 113/113 [==============================] - 2s 2ms/step - loss: 0.1200 - recall: 0.7730 - val_loss: 0.7818 - val_recall: 1.0000
# Epoch 2/500
# 113/113 [==============================] - 0s 1ms/step - loss: 0.1143 - recall: 1.0000 - val_loss: 0.8694 - val_recall: 1.0000
# Epoch 3/500
# 113/113 [==============================] - 0s 1ms/step - loss: 0.1108 - recall: 1.0000 - val_loss: 0.8879 - val_recall: 1.0000
# Epoch 4/500
# 113/113 [==============================] - 0s 1ms/step - loss: 0.1087 - recall: 1.0000 - val_loss: 0.8834 - val_recall: 1.0000
# Epoch 5/500
# 113/113 [==============================] - 0s 1ms/step - loss: 0.1070 - recall: 0.9952 - val_loss: 0.9083 - val_recall: 1.0000
# Epoch 6/500
# 113/113 [==============================] - 0s 1ms/step - loss: 0.1055 - recall: 0.9877 - val_loss: 0.8673 - val_recall: 0.9325
# Epoch 7/500
# ...

# %%
y_pred = (model7.predict(X_test) > 0.5).astype("int32")
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# 63/63 [==============================] - 0s 765us/step
# [[   0 1593]
#  [   0  407]]
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00      1593
#            1       0.20      1.00      0.34       407
#
#     accuracy                           0.20      2000
#    macro avg       0.10      0.50      0.17      2000
# weighted avg       0.04      0.20      0.07      2000
# C:\Users\nurda\anaconda3\envs\kerasenv\lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %%
trial_metric = "val_recall"  # veya "val_precision"
batch_size = 36

def create_model(trial: optuna.trial.Trial) -> Sequential:
    n_units1 = trial.suggest_int("n_units1", 8, 128)
    n_units2 = trial.suggest_int("n_units2", 8, 128)
    optimizer_name = trial.suggest_categorical("optimizer", ["Adam", "Adadelta", "RMSprop", "Nadam"])
    learning_rate = trial.suggest_float("learning_rate", 1e-5, 1.3e-1, log=True)

    optimizer_dict = {
        "Adam": Adam,
        "Adadelta": Adadelta,
        "RMSprop": RMSprop,
        "Nadam": Nadam
    }

    optimizer_class = optimizer_dict[optimizer_name]

    model = Sequential()
    model.add(Dense(n_units1, input_dim=X_train.shape[1], activation="relu"))
    model.add(Dense(n_units2, activation="relu"))
    model.add(Dense(1, activation="sigmoid"))
    model.compile(
        loss="binary_crossentropy",
        optimizer=optimizer_class(learning_rate=learning_rate),
        metrics=[tf.keras.metrics.Precision(name="precision"), tf.keras.metrics.Recall(name="recall")],
    )
    return model


def objective(trial: optuna.trial.Trial) -> float:
    model = create_model(trial)
    w0 = trial.suggest_float("w0", 0.01, 5, log=True)
    w1 = trial.suggest_float("w1", 0.01, 5, log=True)
    early_stop = EarlyStopping(monitor=trial_metric, mode="max", verbose=1, patience=15, restore_best_weights=True)
    
    history = model.fit(
        X_train,
        y_train,
        validation_data=(X_test, y_test),
        batch_size=batch_size,
        epochs=100,
        callbacks=[early_stop],
        class_weight={0: w0, 1: w1},
        verbose=0,
    )
    score = max(history.history[trial_metric])
    return score

# %%
study = optuna.create_study(direction="maximize")
study.optimize(objective, n_trials=10)
# Out:
# [I 2024-07-21 22:20:29,869] A new study created in memory with name: no-name-698ae691-fd31-4019-9fbe-8317fb95c379
# [W 2024-07-21 22:20:29,874] Trial 0 failed with parameters: {'n_units1': 90, 'n_units2': 100, 'optimizer': 'Adam', 'learning_rate': 4.352868487906285e-05} because of the following error: NameError("name 'X_train_scaled' is not defined").
# Traceback (most recent call last):
#   File "C:\Users\nurda\anaconda3\envs\kerasenv\lib\site-packages\optuna\study\_optimize.py", line 196, in _run_trial
#     value_or_values = func(trial)
#   File "C:\Users\nurda\AppData\Local\Temp\ipykernel_15636\2223343270.py", line 32, in objective
#     model = create_model(trial)
#   File "C:\Users\nurda\AppData\Local\Temp\ipykernel_15636\2223343270.py", line 20, in create_model
#     model.add(Dense(n_units1, input_dim=X_train_scaled.shape[1], activation="relu"))
# NameError: name 'X_train_scaled' is not defined
# [W 2024-07-21 22:20:29,874] Trial 0 failed with value None.
# ...

# %%
best_params = study.best_params
unit1 = best_params["n_units1"]
unit2 = best_params["n_units2"]
optimizer_name = best_params["optimizer"]
learning_rate = best_params["learning_rate"]
w0 = best_params["w0"]
w1 = best_params["w1"]

# %%
optimizer_dict = {
    "Adam": Adam,
    "Adadelta": Adadelta,
    "RMSprop": RMSprop,
    "Nadam": Nadam
}

optimizer_class = optimizer_dict[optimizer_name]

model = Sequential()
model.add(Dense(unit1, input_dim=X_train_scaled.shape[1], activation="relu"))
model.add(Dense(unit2, activation="relu"))
model.add(Dense(1, activation="sigmoid"))
model.compile(
    optimizer=optimizer_class(learning_rate=learning_rate),
    loss="binary_crossentropy",
    metrics=[tf.keras.metrics.Precision(name="precision"), tf.keras.metrics.Recall(name="recall")]
)

# %%
early_stop = EarlyStopping(monitor=trial_metric, mode="max", verbose=1, patience=15, restore_best_weights=True)

# %%
history = model.fit(
    X_train_scaled,
    y_train,
    validation_split=0.1,
    batch_size=batch_size,
    epochs=100,
    callbacks=[early_stop],
    class_weight={0: w0, 1: w1},
    verbose=1
)

# %%
history_df = pd.DataFrame(history.history)

import matplotlib.pyplot as plt

fig, axes = plt.subplots(2, 1, figsize=(8, 10))

axes[0].plot(history_df["loss"], label="Training Loss")
axes[0].plot(history_df["val_loss"], label="Validation Loss")
axes[0].set_title("Model Loss")
axes[0].legend()

axes[1].plot(history_df["precision"], label="Training Precision")
axes[1].plot(history_df["val_precision"], label="Validation Precision")
axes[1].plot(history_df["recall"], label="Training Recall")
axes[1].plot(history_df["val_recall"], label="Validation Recall")
axes[1].set_title("Model Precision and Recall")
axes[1].legend()

plt.show()

# %%
# Create an Optuna study to maximize the objective function
study = optuna.create_study(direction="maximize")

# Run the optimization for 25 trials
study.optimize(objective, n_trials=25)

# Get the best hyperparameters found by Optuna
best_params = study.best_params
best_params
# Out:
# [I 2024-07-21 21:59:27,486] A new study created in memory with name: no-name-58d42021-777c-4b9f-9533-4df2f4f2da19
# C:\Users\nurda\AppData\Local\Temp\ipykernel_15636\3744574348.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 1e-5, 1.3e-1)
# C:\Users\nurda\AppData\Local\Temp\ipykernel_15636\3744574348.py:26: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   w0 = trial.suggest_loguniform("w0", 0.01, 5)
# ...

# %%
unit1 = study.best_params["n_units1"]
unit2 = study.best_params["n_units2"]
optimizer_class = study.best_params["optimizer"]
learning_rate = study.best_params["learning_rate"]
w0 = study.best_params["w0"]
w1 = study.best_params["w1"]

model = Sequential()
model.add(Dense(unit1, activation="relu", input_dim=X_train.shape[1]))
model.add(Dense(unit2, activation="relu"))
model.add(Dense(1, activation="sigmoid"))

optimizer_instance = optimizer_class(learning_rate=learning_rate)
model.compile(optimizer=optimizer_instance, loss="binary_crossentropy", metrics=["Recall"])

# Early stopping callback
early_stop = EarlyStopping(monitor="val_recall", mode="max", verbose=1, patience=15, restore_best_weights=True)

history = model.fit(
    X_train,
    y_train,
    validation_split=0.1,
    batch_size=batch_size,
    epochs=100,
    callbacks=[early_stop],
    class_weight={0: w0, 1: w1},
    verbose=1,
)
# Out:
# Epoch 1/100
# 180/180 [==============================] - 1s 2ms/step - loss: 0.0423 - recall: 0.9977 - val_loss: 3.3016 - val_recall: 1.0000
# Epoch 2/100
# 180/180 [==============================] - 0s 1ms/step - loss: 0.0393 - recall: 1.0000 - val_loss: 2.8027 - val_recall: 1.0000
# Epoch 3/100
# 180/180 [==============================] - 0s 979us/step - loss: 0.0396 - recall: 1.0000 - val_loss: 2.7740 - val_recall: 1.0000
# Epoch 4/100
# 180/180 [==============================] - 0s 952us/step - loss: 0.0392 - recall: 1.0000 - val_loss: 2.8748 - val_recall: 1.0000
# Epoch 5/100
# 180/180 [==============================] - 0s 983us/step - loss: 0.0389 - recall: 1.0000 - val_loss: 3.0368 - val_recall: 1.0000
# Epoch 6/100
# 180/180 [==============================] - 0s 1ms/step - loss: 0.0387 - recall: 1.0000 - val_loss: 2.6628 - val_recall: 1.0000
# Epoch 7/100
# ...

# %%
model.summary()
# Out:
# Model: "sequential_191"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_602 (Dense)           (None, 11)                132
#
#  dense_603 (Dense)           (None, 76)                912
#
#  dense_604 (Dense)           (None, 1)                 77
#
# ...
# Total params: 1121 (4.38 KB)
# Trainable params: 1121 (4.38 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ### Evaluate The Model
#
# - Plot the model history to observe the changing of metrics
# - Make prediction to see "confusion matrix" and "classification report"
# - Check ROC (Receiver Operating Curve) and AUC (Area Under Curve) for the model

# %%
history_df = pd.DataFrame(history.history)
history_df.head()
# Out:
#    loss  recall  val_loss  val_recall
# 0 0.042   0.998     3.302       1.000
# 1 0.039   1.000     2.803       1.000
# 2 0.040   1.000     2.774       1.000
# 3 0.039   1.000     2.875       1.000
# 4 0.039   1.000     3.037       1.000

# %%
pd.DataFrame(history_df).plot()
# Out:
# <Axes: >

# %%
y_pred = (model.predict(X_test) > 0.5).astype("int32")
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# 63/63 [==============================] - 0s 625us/step
# [[   0 1593]
#  [   0  407]]
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00      1593
#            1       0.20      1.00      0.34       407
#
#     accuracy                           0.20      2000
#    macro avg       0.10      0.50      0.17      2000
# weighted avg       0.04      0.20      0.07      2000
# C:\Users\nurda\anaconda3\envs\kerasenv\lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %%
y_pred_proba = model.predict(X_test)
RocCurveDisplay.from_predictions(y_test, y_pred_proba)
PrecisionRecallDisplay.from_predictions(y_test, y_pred_proba)

# %%
roc_auc_score(y_test, y_pred_proba)

# %% [markdown]
# # Final Model and Model Deployment

# %%
compare= pd.DataFrame({"Methods": ["Non Class-weight", "Class-weight",  "Class-weight,learning_rate",
                                 "Class-weight,learning_rate,dropout","Class-weight,Learning_rate,Earlystop-val_loss", 
                                   "Class-weight,Learning_rate,Earlystop-val_recall","Optuna"],
                       "Precision": [model_precision, model2_precision, model3_precision, model4_precision,
                                     model5_precision, model6_precision, model7_precision],
                       "Recall": [model_recall, model2_recall, model3_recall, model4_recall,
                                  model5_recall, model6_recall, model7_recall],
                       "AP": [model_AP, model2_AP, model3_AP, model4_AP,
                              model5_AP,model6_AP,model7_AP]})

compare

# %%
import pickle

pickle.dump(scaler, open("scaler_cancer", "wb"))

# %%
loss, accuracy = model.evaluate(X_test, y_test, verbose=0)
print("loss: ", loss)
print("accuracy: ", accuracy)

# %%
y_pred = model.predict(X_test) > 0.5
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))

# %%
model.save("model_cancer.h5")

# %%
from tensorflow.keras.models import load_model
import pickle

# %%
model_cancer = load_model("model_cancer.h5")
scaler_cancer = pickle.load(open("scaler_cancer", "rb"))

# %% [markdown]
# ## Prediction

# %%
single_churn = df.drop("Exited", axis=1).iloc[11:12, :]
single_churn

# %% [markdown]
# ___
#
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid" alt="CLRSWY"></p>
#
# ___
